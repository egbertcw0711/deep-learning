# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)

# %%
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 17005207
# Unique words: 253854

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
# print(int_words[0:100])

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# ===============================================================================================
# **(MODIFIED)
#  In this notebook, I tried to used the formula used in paper, you can find it in [this github repo](https://github.com/chrisjmccormick/word2vec_commented/blob/master/word2vec.c) **
#
# $$ P(w_i) = 1 - ({\sqrt{\frac{x}{0.001}} + 1}) * {\frac{0.001}{x}} $$
#
# where $x$ is the frequency of a word in the text
#
# ===============================================================================================
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random, math

random.seed(0) # make it replicable

word_counts  = Counter(words) # count the frequency of words in the dataset
train_words = []
total_words = len(words)

def drop_prob(x):
    ran = (math.sqrt(x/0.001) + 1) * (0.001/x)
    return 1 - ran

for idx in int_words:
    word = int_to_vocab[idx]
    f = word_counts[word]
    x = f/total_words
    if random.random() < (1 - drop_prob(x)):
        train_words.append(idx)
print(len(train_words))
# Out:
# 12819498

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
#     R = random.randint(1,window_size)
    R = window_size
    start = idx - R if idx-R>=0 else 0
    end = idx + R if idx+R<=len(words) else len(words)
    copy_words = words[:]
    res = copy_words[start:end+1]
    res.pop(idx-start)
    return res

# %%
# Test get_target
# print(words[95:106])
print(get_target(words, 100))
# Out:
# ['abolished', 'although', 'there', 'are', 'differing', 'of', 'what', 'this', 'means', 'anarchism']

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(batch_size):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
#             print(len(batch_y))
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        
        yield x, y

# %%
# tra, lab = next(get_batches(words,20))
tra, lab = next(get_batches(train_words,8))
# print(len(tra))
# print(lab)

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(dtype=tf.int32,shape=[None])
    labels = tf.placeholder(dtype=tf.int32,shape=[None,1])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200# Number of embedding features 
with train_graph.as_default():
    embedding =tf.Variable(tf.random_uniform([n_vocab,n_embedding],-1.0,1.0))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding,inputs)# use tf.nn.embedding_lookup to get the hidden layer output
                                                    # inputs are tokenized data

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 200
with train_graph.as_default():
    softmax_w = tf.Variable(\
                   tf.truncated_normal([n_vocab, n_embedding],\
                            stddev=1.0/math.sqrt(n_embedding)))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros([n_vocab]))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# 子目录或文件 checkpoints 已经存在。

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 5
batch_size = 100
window_size = 5

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/5 Iteration: 100 Avg. Training loss: 6.6608 0.8973 sec/batch
# Epoch 1/5 Iteration: 200 Avg. Training loss: 6.6668 0.8921 sec/batch
# Epoch 1/5 Iteration: 300 Avg. Training loss: 6.7988 0.9182 sec/batch
# Epoch 1/5 Iteration: 400 Avg. Training loss: 6.4987 0.9179 sec/batch
# Epoch 1/5 Iteration: 500 Avg. Training loss: 6.2365 0.8977 sec/batch
# Epoch 1/5 Iteration: 600 Avg. Training loss: 6.3508 0.9058 sec/batch
# Epoch 1/5 Iteration: 700 Avg. Training loss: 6.1842 0.9058 sec/batch
# Epoch 1/5 Iteration: 800 Avg. Training loss: 6.1996 0.9291 sec/batch
# Epoch 1/5 Iteration: 900 Avg. Training loss: 5.8869 0.9429 sec/batch
# Epoch 1/5 Iteration: 1000 Avg. Training loss: 5.5733 0.9074 sec/batch
# Nearest to use: africa, outmoded, synapses, additionally, emotion, spermicide, printerfriendly, kaleidoscope,
# Nearest to would: cranham, chatterbox, immediately, grabthar, hobkirk, sno, gwebcache, partholon,
# Nearest to had: bncs, klef, erators, straightahead, heswall, prenzlauer, tailgating, advisability,
# Nearest to when: citazione, illuminate, fluttering, velis, obronnych, yfb, swasthy, mcnally,
# Nearest to new: zervic, cocawine, isdb, repentant, edna, kivu, msrtc, britsh,
# Nearest to war: khalifas, twah, brundtland, willadsen, pallo, undset, nokkrum, rahway,
# Nearest to to: stirrer, nicorette, isoalkanes, cascadas, dragondos, sete, lotte, fifth,
# Nearest to by: one, contravariance, sltb, novaehollandiae, claverie, richtmyer, mentha, uturoa,
# Nearest to freedom: morgenlandfahrt, lechers, schwer, paros, samaipata, thrush, crockett, pathlength,
# Nearest to bill: thrown, botomian, fadiman, aguto, coanna, phenanthrine, polygalales, cemal,
# Nearest to prince: ulcc, adsp, sogno, kro, slates, baalhazor, halifax, heijo,
# Nearest to placed: umarkot, restfully, triumphalism, quantic, ndegeocello, kentaga, eyewitnes, freeholders,
# Nearest to ice: mumbi, haydnhaus, cisl, mmegi, harmar, bastarache, wrenboys, cholsey,
# Nearest to mathematics: unmogip, scintillating, polops, arabic, lipases, cleckley, haquit, bedsides,
# Nearest to primarily: cancellation, koran, mckinnie, grizzlybear, hirah, hooramarju, arrhidaeus, enmity,
# Nearest to frac: macinnis, chirassi, hoonacker, qualifiers, echinocereus, giants, skybolt, nerves,
# Epoch 1/5 Iteration: 1100 Avg. Training loss: 5.3535 0.9268 sec/batch
# Epoch 1/5 Iteration: 1200 Avg. Training loss: 5.2763 0.9092 sec/batch
# Epoch 1/5 Iteration: 1300 Avg. Training loss: 5.1206 0.9121 sec/batch
# Epoch 1/5 Iteration: 1400 Avg. Training loss: 4.9237 0.9104 sec/batch
# Epoch 1/5 Iteration: 1500 Avg. Training loss: 4.6249 0.9129 sec/batch
# Epoch 1/5 Iteration: 1600 Avg. Training loss: 4.8347 0.9187 sec/batch
# Epoch 1/5 Iteration: 1700 Avg. Training loss: 4.4522 0.9151 sec/batch
# Epoch 1/5 Iteration: 1800 Avg. Training loss: 4.5752 0.9183 sec/batch
# Epoch 1/5 Iteration: 1900 Avg. Training loss: 4.5477 0.9164 sec/batch
# Epoch 1/5 Iteration: 2000 Avg. Training loss: 4.3853 0.9159 sec/batch
# Nearest to use: africa, kaleidoscope, additionally, emotion, and, years, broke, synapses,
# Nearest to would: immediately, cranham, chatterbox, instead, grabthar, any, distinct, both,
# Nearest to had: flight, klef, motion, continent, has, alaska, early, after,
# Nearest to when: level, illuminate, important, citazione, out, velis, absolutist, erhalt,
# Nearest to new: zervic, repentant, kivu, greatly, scarab, shreklisch, planned, isdb,
# Nearest to war: will, khalifas, muslim, twah, central, v, brundtland, enter,
# Nearest to to: still, stirrer, isoalkanes, nicorette, dragondos, similar, atoms, sete,
# Nearest to by: while, several, contravariance, one, sltb, fifth, claverie, west,
# Nearest to freedom: morgenlandfahrt, paros, lechers, thrush, crockett, schwer, samaipata, obes,
# Nearest to bill: thrown, botomian, fadiman, aguto, coanna, plastering, polygalales, fmaj,
# Nearest to prince: ulcc, sogno, adsp, kro, dealt, baalhazor, halifax, holonic,
# Nearest to placed: umarkot, quantic, triumphalism, restfully, ndegeocello, kentaga, groenewegen, libice,
# Nearest to ice: haydnhaus, bogs, cisl, navigate, thebestnotes, juliae, calistoga, swre,
# Nearest to mathematics: arabic, nicht, unmogip, difference, lipases, abashed, polops, bedsides,
# Nearest to primarily: an, just, cancellation, mckinnie, invoke, hirah, arrhidaeus, history,
# Nearest to frac: macinnis, chirassi, hoonacker, qualifiers, giants, echinocereus, skybolt, nerves,
# Epoch 1/5 Iteration: 2100 Avg. Training loss: 4.2411 0.9394 sec/batch
# Epoch 1/5 Iteration: 2200 Avg. Training loss: 4.3294 0.9203 sec/batch
# Epoch 1/5 Iteration: 2300 Avg. Training loss: 4.2883 0.9218 sec/batch
# Epoch 1/5 Iteration: 2400 Avg. Training loss: 3.8785 0.9235 sec/batch
# Epoch 1/5 Iteration: 2500 Avg. Training loss: 4.1869 0.9253 sec/batch
# Epoch 1/5 Iteration: 2600 Avg. Training loss: 4.1778 0.9347 sec/batch
# Epoch 1/5 Iteration: 2700 Avg. Training loss: 4.1494 0.9274 sec/batch
# Epoch 1/5 Iteration: 2800 Avg. Training loss: 4.1330 0.9281 sec/batch
# Epoch 1/5 Iteration: 2900 Avg. Training loss: 4.2061 0.9303 sec/batch
# Epoch 1/5 Iteration: 3000 Avg. Training loss: 4.0763 0.9299 sec/batch
# Nearest to use: africa, emotion, additionally, kaleidoscope, broke, synapses, outmoded, money,
# Nearest to would: immediately, cranham, chatterbox, describing, materials, hobkirk, grabthar, distinct,
# Nearest to had: klef, motion, continent, bncs, erators, tailgating, slammed, heswall,
# Nearest to when: citazione, illuminate, wife, velis, level, erhalt, swasthy, assisted,
# Nearest to new: zervic, repentant, planned, kivu, greatly, isdb, shreklisch, wives,
# Nearest to war: v, khalifas, muslim, leave, twah, will, pope, brundtland,
# Nearest to to: stirrer, isoalkanes, nicorette, dragondos, still, sete, abandoned, horror,
# Nearest to by: uturoa, contravariance, reducing, sltb, claverie, pressurisation, several, novaehollandiae,
# Nearest to freedom: morgenlandfahrt, thrush, crockett, paros, probably, lechers, harvest, hardcover,
# Nearest to bill: thrown, botomian, fadiman, expansive, pectus, huv, fmaj, plastering,
# Nearest to prince: sogno, adsp, ulcc, dealt, hall, kro, halifax, should,
# Nearest to placed: umarkot, dead, quantic, triumphalism, outdueling, ndegeocello, libice, groenewegen,
# Nearest to ice: haydnhaus, bogs, cisl, navigate, thebestnotes, juliae, swre, calistoga,
# Nearest to mathematics: arabic, difference, nicht, abashed, mixup, course, unmogip, lipases,
# Nearest to primarily: revolutionary, cancellation, mckinnie, lincoln, arrhidaeus, executed, hirah, invoke,
# Nearest to frac: macinnis, chirassi, hoonacker, qualifiers, echinocereus, skybolt, nerves, giants,
# Epoch 1/5 Iteration: 3100 Avg. Training loss: 3.9116 0.9516 sec/batch
# Epoch 1/5 Iteration: 3200 Avg. Training loss: 3.9080 0.9321 sec/batch
# Epoch 1/5 Iteration: 3300 Avg. Training loss: 3.9803 0.9306 sec/batch
# Epoch 1/5 Iteration: 3400 Avg. Training loss: 3.9008 0.9348 sec/batch
# Epoch 1/5 Iteration: 3500 Avg. Training loss: 3.9183 0.9354 sec/batch
# Epoch 1/5 Iteration: 3600 Avg. Training loss: 3.7798 0.9385 sec/batch
# Epoch 1/5 Iteration: 3700 Avg. Training loss: 3.9175 0.9421 sec/batch
# Epoch 1/5 Iteration: 3800 Avg. Training loss: 3.8295 0.9383 sec/batch
# Epoch 1/5 Iteration: 3900 Avg. Training loss: 3.8028 0.9411 sec/batch
# Epoch 1/5 Iteration: 4000 Avg. Training loss: 3.8239 0.9428 sec/batch
# Nearest to use: africa, emotion, additionally, broke, kaleidoscope, synapses, money, outmoded,
# Nearest to would: immediately, cranham, chatterbox, describing, materials, faith, researchers, hobkirk,
# Nearest to had: klef, bncs, erators, motion, continent, heswall, tailgating, slammed,
# Nearest to when: illuminate, citazione, velis, le, erhalt, swasthy, fluttering, assembled,
# Nearest to new: zervic, repentant, edna, kivu, isdb, greatly, shreklisch, databases,
# Nearest to war: v, khalifas, meaningful, pope, muslim, twah, brundtland, beliefs,
# Nearest to to: isoalkanes, stirrer, nicorette, dragondos, atoms, abandoned, horror, still,
# Nearest to by: reducing, uturoa, contravariance, sltb, claverie, bcie, novaehollandiae, casterman,
# Nearest to freedom: morgenlandfahrt, thrush, crockett, probably, paros, fill, hardcover, victory,
# Nearest to bill: thrown, botomian, fadiman, expansive, infections, huv, represent, pectus,
# Nearest to prince: dealt, sogno, hall, adsp, royal, ulcc, taxes, kro,
# Nearest to placed: umarkot, quantic, dead, triumphalism, restfully, outdueling, libice, ndegeocello,
# Nearest to ice: thebestnotes, bogs, haydnhaus, lack, navigate, cisl, oxygen, juliae,
# Nearest to mathematics: arabic, difference, nicht, abashed, mixup, course, vol, unmogip,
# Nearest to primarily: cancellation, mckinnie, lincoln, revolutionary, arrhidaeus, hirah, homer, valence,
# Nearest to frac: macinnis, chirassi, hoonacker, qualifiers, echinocereus, skybolt, nerves, giants,
# Epoch 1/5 Iteration: 4100 Avg. Training loss: 3.9268 0.9606 sec/batch
# Epoch 1/5 Iteration: 4200 Avg. Training loss: 3.8351 0.9434 sec/batch
# Epoch 1/5 Iteration: 4300 Avg. Training loss: 3.8157 0.9467 sec/batch
# Epoch 1/5 Iteration: 4400 Avg. Training loss: 3.6019 0.9433 sec/batch
# Epoch 1/5 Iteration: 4500 Avg. Training loss: 3.8232 0.9499 sec/batch
# Epoch 1/5 Iteration: 4600 Avg. Training loss: 3.7231 0.9437 sec/batch
# Epoch 1/5 Iteration: 4700 Avg. Training loss: 3.5142 0.9432 sec/batch
# Epoch 1/5 Iteration: 4800 Avg. Training loss: 3.7170 0.9461 sec/batch
# Epoch 1/5 Iteration: 4900 Avg. Training loss: 3.6981 0.9490 sec/batch
# Epoch 1/5 Iteration: 5000 Avg. Training loss: 3.7238 0.9485 sec/batch
# Nearest to use: africa, emotion, kaleidoscope, additionally, broke, synapses, money, snowbird,
# Nearest to would: immediately, cranham, chatterbox, describing, materials, reminding, faith, distinct,
# Nearest to had: hospital, bncs, erators, tailgating, heswall, klef, motion, straightahead,
# Nearest to when: illuminate, citazione, velis, erhalt, le, assisted, mcnally, fluttering,
# Nearest to new: zervic, repentant, edna, databases, kivu, shreklisch, isdb, greatly,
# Nearest to war: pope, khalifas, muslim, meaningful, twah, brundtland, v, recording,
# Nearest to to: isoalkanes, stirrer, nicorette, dragondos, abandoned, sete, developing, atoms,
# Nearest to by: reducing, uturoa, claverie, sltb, contravariance, bcie, casterman, asa,
# Nearest to freedom: morgenlandfahrt, thrush, paros, crockett, probably, fill, hardcover, electrically,
# Nearest to bill: thrown, botomian, fadiman, expansive, infections, huv, coanna, pectus,
# Nearest to prince: dealt, sogno, hall, tests, adsp, taxes, royal, ulcc,
# Nearest to placed: quantic, umarkot, dead, triumphalism, copenhagen, physicists, overhead, secular,
# Nearest to ice: thebestnotes, haydnhaus, bogs, muslim, navigate, cisl, prussian, lack,
# Nearest to mathematics: arabic, difference, nicht, saved, mixup, abashed, unmogip, aims,
# Nearest to primarily: koran, homer, cancellation, lincoln, mckinnie, invoke, arrhidaeus, hirah,
# Nearest to frac: chirassi, giants, hoonacker, macinnis, skybolt, qualifiers, nerves, echinocereus,
# Epoch 1/5 Iteration: 5100 Avg. Training loss: 3.6507 0.9678 sec/batch
# Epoch 1/5 Iteration: 5200 Avg. Training loss: 3.7023 0.9473 sec/batch
# Epoch 1/5 Iteration: 5300 Avg. Training loss: 3.6372 0.9512 sec/batch
# Epoch 1/5 Iteration: 5400 Avg. Training loss: 3.5501 0.9510 sec/batch
# Epoch 1/5 Iteration: 5500 Avg. Training loss: 3.6390 0.9566 sec/batch
# Epoch 1/5 Iteration: 5600 Avg. Training loss: 3.6665 0.9568 sec/batch
# Epoch 1/5 Iteration: 5700 Avg. Training loss: 3.4994 0.9556 sec/batch
# Epoch 1/5 Iteration: 5800 Avg. Training loss: 3.5026 0.9555 sec/batch
# Epoch 1/5 Iteration: 5900 Avg. Training loss: 3.5977 0.9588 sec/batch
# Epoch 1/5 Iteration: 6000 Avg. Training loss: 3.5991 0.9559 sec/batch
# Nearest to use: emotion, africa, kaleidoscope, additionally, broke, synapses, snowbird, finds,
# Nearest to would: immediately, chatterbox, cranham, describing, reminding, faith, materials, dc,
# Nearest to had: funk, hospital, bncs, tailgating, erators, klef, heswall, straightahead,
# Nearest to when: illuminate, citazione, assembled, interstate, cordiale, mcnally, fluttering, erhalt,
# Nearest to new: zervic, repentant, edna, databases, kivu, isdb, wives, cocawine,
# Nearest to war: pope, meaningful, khalifas, v, twah, brundtland, muslim, recording,
# Nearest to to: stirrer, nicorette, abandoned, dragondos, isoalkanes, sete, developing, addressbook,
# Nearest to by: reducing, claverie, contravariance, sltb, uturoa, asa, bcie, novaehollandiae,
# Nearest to freedom: morgenlandfahrt, paros, thrush, crockett, probably, harvest, electrically, fill,
# Nearest to bill: thrown, botomian, expansive, fadiman, infections, huv, earl, tokyo,
# Nearest to prince: sogno, dealt, adsp, hall, ulcc, royal, taxes, tests,
# Nearest to placed: quantic, umarkot, dead, copenhagen, overhead, physicists, restfully, ndegeocello,
# Nearest to ice: thebestnotes, cisl, haydnhaus, theorist, muslim, navigate, juliae, bogs,
# Nearest to mathematics: arabic, nicht, difference, mixup, abashed, aims, saved, shortcuts,
# Nearest to primarily: koran, cancellation, homer, mckinnie, invoke, arrhidaeus, zerbo, hirah,
# Nearest to frac: giants, chirassi, hoonacker, skybolt, macinnis, qualifiers, demonstrated, asteroids,
# Epoch 1/5 Iteration: 6100 Avg. Training loss: 3.5895 0.9795 sec/batch
# Epoch 1/5 Iteration: 6200 Avg. Training loss: 3.6323 0.9594 sec/batch
# Epoch 1/5 Iteration: 6300 Avg. Training loss: 3.5832 0.9623 sec/batch
# Epoch 1/5 Iteration: 6400 Avg. Training loss: 3.5687 0.9635 sec/batch
# Epoch 1/5 Iteration: 6500 Avg. Training loss: 3.5698 0.9612 sec/batch
# Epoch 1/5 Iteration: 6600 Avg. Training loss: 3.4874 0.9624 sec/batch
# Epoch 1/5 Iteration: 6700 Avg. Training loss: 3.5579 0.9637 sec/batch
# Epoch 1/5 Iteration: 6800 Avg. Training loss: 3.6221 0.9654 sec/batch
# Epoch 1/5 Iteration: 6900 Avg. Training loss: 3.3505 0.9629 sec/batch
# Epoch 1/5 Iteration: 7000 Avg. Training loss: 3.4766 0.9655 sec/batch
# Nearest to use: emotion, africa, kaleidoscope, synapses, money, outmoded, snowbird, broke,
# Nearest to would: immediately, chatterbox, cranham, reminding, dc, hobkirk, materials, angelico,
# Nearest to had: bncs, funk, hospital, tailgating, erators, heswall, klef, nietzsche,
# Nearest to when: illuminate, assembled, citazione, interstate, electro, cordiale, fluttering, erhalt,
# Nearest to new: zervic, repentant, edna, isdb, databases, kivu, cocawine, wiley,
# Nearest to war: pope, twah, brundtland, meaningful, khalifas, v, energetically, heidi,
# Nearest to to: stirrer, dragondos, nicorette, abandoned, isoalkanes, sete, developing, fluorescent,
# Nearest to by: contravariance, claverie, reducing, sltb, uturoa, asa, freely, bcie,
# Nearest to freedom: morgenlandfahrt, crockett, paros, thrush, probably, harvest, fill, hardcover,
# Nearest to bill: thrown, botomian, fadiman, expansive, infections, huv, coanna, plastering,
# Nearest to prince: sogno, dealt, halifax, adsp, ulcc, hall, taxes, royal,
# Nearest to placed: quantic, umarkot, overhead, dead, physicists, ndegeocello, restfully, triumphalism,
# Nearest to ice: thebestnotes, cisl, haydnhaus, muslim, theorist, navigate, juliae, bogs,
# Nearest to mathematics: nicht, arabic, difference, mixup, shortcuts, abashed, aims, saved,
# Nearest to primarily: cancellation, koran, homer, mckinnie, hooramarju, basement, zerbo, arrhidaeus,
# Nearest to frac: giants, chirassi, hoonacker, skybolt, macinnis, asteroids, demonstrated, qualifiers,
# Epoch 1/5 Iteration: 7100 Avg. Training loss: 3.3361 0.9892 sec/batch
# Epoch 1/5 Iteration: 7200 Avg. Training loss: 3.5334 0.9688 sec/batch
# Epoch 1/5 Iteration: 7300 Avg. Training loss: 3.5563 0.9715 sec/batch
# Epoch 1/5 Iteration: 7400 Avg. Training loss: 3.5948 0.9743 sec/batch
# Epoch 1/5 Iteration: 7500 Avg. Training loss: 3.4225 0.9748 sec/batch
# Epoch 1/5 Iteration: 7600 Avg. Training loss: 3.1791 0.9737 sec/batch
# Epoch 1/5 Iteration: 7700 Avg. Training loss: 3.3607 0.9739 sec/batch
# Epoch 1/5 Iteration: 7800 Avg. Training loss: 3.3245 0.9747 sec/batch
# Epoch 1/5 Iteration: 7900 Avg. Training loss: 3.4475 0.9802 sec/batch
# Epoch 1/5 Iteration: 8000 Avg. Training loss: 3.3010 0.9781 sec/batch
# Nearest to use: emotion, africa, kaleidoscope, synapses, outmoded, snowbird, sable, money,
# Nearest to would: chatterbox, immediately, cranham, reminding, materials, dc, hobkirk, angelico,
# Nearest to had: bncs, funk, heswall, hospital, tailgating, nietzsche, erators, corowa,
# Nearest to when: illuminate, assembled, basrah, erhalt, electro, cordiale, interstate, wife,
# Nearest to new: zervic, repentant, edna, kivu, cocawine, databases, isdb, wives,
# Nearest to war: brundtland, twah, khalifas, pope, v, meaningful, appetite, energetically,
# Nearest to to: abandoned, stirrer, dragondos, nicorette, sete, fluorescent, alkene, mata,
# Nearest to by: claverie, uturoa, contravariance, sltb, reducing, asa, franks, novaehollandiae,
# Nearest to freedom: morgenlandfahrt, crockett, paros, thrush, probably, despues, fill, harvest,
# Nearest to bill: thrown, botomian, expansive, fadiman, infections, earl, huv, coanna,
# Nearest to prince: sogno, dealt, hall, ulcc, macrobiology, expired, taxes, halifax,
# Nearest to placed: umarkot, quantic, overhead, restfully, triumphalism, kentaga, physicists, outdueling,
# Nearest to ice: cisl, thebestnotes, haydnhaus, mumbi, bogs, juliae, theorist, cgxind,
# Nearest to mathematics: nicht, difference, arabic, mixup, aims, shortcuts, abashed, kreiss,
# Nearest to primarily: cancellation, koran, enmity, hooramarju, reinforced, arrhidaeus, homer, mckinnie,
# Nearest to frac: giants, chirassi, hoonacker, skybolt, rebuilding, macinnis, asteroids, qualifiers,
# Epoch 1/5 Iteration: 8100 Avg. Training loss: 3.3547 1.0032 sec/batch
# Epoch 1/5 Iteration: 8200 Avg. Training loss: 3.3428 0.9785 sec/batch
# Epoch 1/5 Iteration: 8300 Avg. Training loss: 3.3966 0.9857 sec/batch
# Epoch 1/5 Iteration: 8400 Avg. Training loss: 3.3103 0.9792 sec/batch
# Epoch 1/5 Iteration: 8500 Avg. Training loss: 3.2624 0.9797 sec/batch
# Epoch 1/5 Iteration: 8600 Avg. Training loss: 3.3725 0.9823 sec/batch
# Epoch 1/5 Iteration: 8700 Avg. Training loss: 3.3527 0.9836 sec/batch
# Epoch 1/5 Iteration: 8800 Avg. Training loss: 3.3345 0.9855 sec/batch
# Epoch 1/5 Iteration: 8900 Avg. Training loss: 3.4290 0.9850 sec/batch
# Epoch 1/5 Iteration: 9000 Avg. Training loss: 3.3894 0.9851 sec/batch
# Nearest to use: emotion, africa, kaleidoscope, synapses, outmoded, outfielder, snowbird, sable,
# Nearest to would: chatterbox, immediately, cranham, reminding, describing, dc, angelico, hobkirk,
# Nearest to had: funk, bncs, tailgating, hospital, heswall, nietzsche, erators, corowa,
# Nearest to when: illuminate, assembled, basrah, interstate, electro, yfb, erhalt, cordiale,
# Nearest to new: zervic, repentant, edna, kivu, cocawine, isdb, databases, wiley,
# Nearest to war: brundtland, khalifas, twah, pope, energetically, appetite, heidi, v,
# Nearest to to: abandoned, dragondos, stirrer, nicorette, sete, trotter, fluorescent, isoalkanes,
# Nearest to by: claverie, reducing, uturoa, sltb, contravariance, asa, qasr, franks,
# Nearest to freedom: morgenlandfahrt, crockett, paros, thrush, probably, despues, hardcover, lechers,
# Nearest to bill: thrown, botomian, fadiman, plastering, expansive, coanna, huv, pectus,
# Nearest to prince: sogno, hall, ulcc, dealt, macrobiology, expired, taxes, tenth,
# Nearest to placed: umarkot, quantic, overhead, triumphalism, kentaga, restfully, outdueling, physicists,
# Nearest to ice: cisl, haydnhaus, mumbi, juliae, thebestnotes, theorist, cholsey, navigate,
# Nearest to mathematics: nicht, arabic, difference, mixup, shortcuts, kreiss, abashed, aims,
# Nearest to primarily: cancellation, koran, arrhidaeus, enmity, basement, hooramarju, homer, mckinnie,
# Nearest to frac: chirassi, giants, hoonacker, skybolt, macinnis, asteroids, rebuilding, qualifiers,
# Epoch 1/5 Iteration: 9100 Avg. Training loss: 3.5088 1.0071 sec/batch
# Epoch 1/5 Iteration: 9200 Avg. Training loss: 3.4207 0.9927 sec/batch
# Epoch 1/5 Iteration: 9300 Avg. Training loss: 3.5366 0.9932 sec/batch
# Epoch 1/5 Iteration: 9400 Avg. Training loss: 3.3738 0.9883 sec/batch
# Epoch 1/5 Iteration: 9500 Avg. Training loss: 3.4591 0.9914 sec/batch
# Epoch 1/5 Iteration: 9600 Avg. Training loss: 3.3594 0.9917 sec/batch
# Epoch 1/5 Iteration: 9700 Avg. Training loss: 3.2224 0.9955 sec/batch
# Epoch 1/5 Iteration: 9800 Avg. Training loss: 3.0983 0.9964 sec/batch
# Epoch 1/5 Iteration: 9900 Avg. Training loss: 3.5078 0.9952 sec/batch
# Epoch 1/5 Iteration: 10000 Avg. Training loss: 3.2961 0.9971 sec/batch
# Nearest to use: emotion, africa, sable, kaleidoscope, synapses, outmoded, snowbird, fischettis,
# Nearest to would: chatterbox, immediately, cranham, reminding, sno, partholon, praef, describing,
# Nearest to had: bncs, funk, tailgating, hospital, heswall, erators, nietzsche, ira,
# Nearest to when: illuminate, assembled, cordiale, citazione, yfb, electro, basrah, fluttering,
# Nearest to new: zervic, repentant, edna, kivu, cocawine, databases, transferases, msrtc,
# Nearest to war: twah, brundtland, khalifas, energetically, heidi, pope, clara, nokkrum,
# Nearest to to: dragondos, abandoned, nicorette, stirrer, trotter, sete, isoalkanes, mata,
# Nearest to by: reducing, claverie, sltb, contravariance, asa, qasr, uturoa, franks,
# Nearest to freedom: morgenlandfahrt, crockett, probably, paros, thrush, despues, electrically, hardcover,
# Nearest to bill: thrown, botomian, fadiman, coanna, plastering, huv, tokyo, infections,
# Nearest to prince: sogno, hall, ulcc, tenth, macrobiology, expired, royal, dealt,
# Nearest to placed: umarkot, quantic, overhead, yojimbo, kentaga, outdueling, restfully, triumphalism,
# Nearest to ice: cisl, mumbi, haydnhaus, juliae, thebestnotes, cholsey, cgxind, theorist,
# Nearest to mathematics: nicht, difference, arabic, shortcuts, kreiss, mixup, abashed, modes,
# Nearest to primarily: cancellation, koran, enmity, arrhidaeus, basement, hooramarju, reinforced, mckinnie,
# Nearest to frac: chirassi, giants, hoonacker, skybolt, rebuilding, spacewalks, asteroids, enigmatic,
# Epoch 1/5 Iteration: 10100 Avg. Training loss: 3.2694 1.0200 sec/batch
# Epoch 1/5 Iteration: 10200 Avg. Training loss: 3.2849 0.9971 sec/batch
# Epoch 1/5 Iteration: 10300 Avg. Training loss: 3.2476 0.9991 sec/batch
# Epoch 1/5 Iteration: 10400 Avg. Training loss: 3.3410 1.0000 sec/batch
# Epoch 1/5 Iteration: 10500 Avg. Training loss: 3.3505 1.0010 sec/batch
# Epoch 1/5 Iteration: 10600 Avg. Training loss: 3.4086 1.0005 sec/batch
# Epoch 1/5 Iteration: 10700 Avg. Training loss: 3.3910 1.0006 sec/batch
# Epoch 1/5 Iteration: 10800 Avg. Training loss: 3.3426 1.0004 sec/batch
# Epoch 1/5 Iteration: 10900 Avg. Training loss: 3.4430 1.0012 sec/batch
# Epoch 1/5 Iteration: 11000 Avg. Training loss: 3.4093 1.0042 sec/batch
# Nearest to use: emotion, africa, sable, kaleidoscope, synapses, snowbird, outmoded, finds,
# Nearest to would: chatterbox, immediately, cranham, reminding, athletics, sno, praef, ll,
# Nearest to had: funk, bncs, tailgating, heswall, erators, ira, hospital, zemsk,
# Nearest to when: illuminate, assembled, cordiale, fluttering, citazione, yfb, electro, basrah,
# Nearest to new: zervic, repentant, edna, kivu, cocawine, msrtc, wiley, databases,
# Nearest to war: twah, brundtland, khalifas, heidi, energetically, nokkrum, appetite, muslim,
# Nearest to to: dragondos, abandoned, trotter, nicorette, sete, camel, mata, stirrer,
# Nearest to by: claverie, reducing, sltb, asa, contravariance, silkworth, paraded, qasr,
# Nearest to freedom: morgenlandfahrt, crockett, paros, probably, thrush, despues, electrically, hardcover,
# Nearest to bill: thrown, botomian, fadiman, coanna, plastering, madhukarshah, aguto, huv,
# Nearest to prince: sogno, ulcc, tenth, hall, macrobiology, adsp, expired, heijo,
# Nearest to placed: umarkot, quantic, overhead, physicists, kentaga, yojimbo, outdueling, libice,
# Nearest to ice: mumbi, cisl, haydnhaus, thebestnotes, juliae, cholsey, cgxind, harmar,
# Nearest to mathematics: arabic, nicht, kreiss, abashed, modes, difference, shortcuts, unmogip,
# Nearest to primarily: cancellation, koran, enmity, arrhidaeus, reinforced, basement, hooramarju, mckinnie,
# Nearest to frac: giants, chirassi, hoonacker, skybolt, colloquial, rebuilding, spacewalks, asteroids,
# Epoch 1/5 Iteration: 11100 Avg. Training loss: 3.3070 1.0251 sec/batch
# Epoch 1/5 Iteration: 11200 Avg. Training loss: 3.3015 1.0134 sec/batch
# Epoch 1/5 Iteration: 11300 Avg. Training loss: 3.3162 1.0051 sec/batch
# Epoch 1/5 Iteration: 11400 Avg. Training loss: 3.2945 1.0070 sec/batch
# Epoch 1/5 Iteration: 11500 Avg. Training loss: 3.2971 1.0037 sec/batch
# Epoch 1/5 Iteration: 11600 Avg. Training loss: 3.3307 1.0753 sec/batch
# Epoch 1/5 Iteration: 11700 Avg. Training loss: 3.3404 1.0150 sec/batch
# Epoch 1/5 Iteration: 11800 Avg. Training loss: 3.3890 1.0229 sec/batch
# Epoch 1/5 Iteration: 11900 Avg. Training loss: 3.3048 1.0975 sec/batch
# Epoch 1/5 Iteration: 12000 Avg. Training loss: 3.2868 1.0411 sec/batch
# Nearest to use: emotion, synapses, africa, sable, kaleidoscope, snowbird, outmoded, fischettis,
# Nearest to would: chatterbox, cranham, immediately, reminding, athletics, unflinchingly, praef, sno,
# Nearest to had: funk, bncs, tailgating, erators, ira, heswall, zemsk, has,
# Nearest to when: illuminate, assembled, fluttering, cordiale, citazione, yfb, basrah, swasthy,
# Nearest to new: zervic, repentant, edna, kivu, cocawine, databases, wiley, msrtc,
# Nearest to war: brundtland, twah, heidi, nokkrum, energetically, khalifas, humilitation, pallo,
# Nearest to to: dragondos, nicorette, trotter, sete, abandoned, stirrer, camel, developing,
# Nearest to by: claverie, reducing, asa, qasr, contravariance, uturoa, silkworth, sltb,
# Nearest to freedom: morgenlandfahrt, paros, crockett, probably, thrush, despues, electrically, lechers,
# Nearest to bill: thrown, botomian, fadiman, coanna, plastering, tokyo, aguto, madhukarshah,
# Nearest to prince: sogno, hall, ulcc, macrobiology, halifax, tenth, fairfax, heijo,
# Nearest to placed: umarkot, quantic, kentaga, overhead, yojimbo, physicists, outdueling, restfully,
# Nearest to ice: mumbi, cisl, haydnhaus, cholsey, juliae, harmar, mmegi, cgxind,
# Nearest to mathematics: nicht, arabic, abashed, difference, kreiss, mixup, modes, shortcuts,
# Nearest to primarily: cancellation, koran, enmity, reinforced, arrhidaeus, basement, hooramarju, zerbo,
# Nearest to frac: giants, chirassi, hoonacker, skybolt, spacewalks, colloquial, macinnis, qualifiers,
# Epoch 1/5 Iteration: 12100 Avg. Training loss: 3.3171 1.0327 sec/batch
# Epoch 1/5 Iteration: 12200 Avg. Training loss: 3.3744 1.0541 sec/batch
# Epoch 1/5 Iteration: 12300 Avg. Training loss: 3.3002 1.0497 sec/batch
# Epoch 1/5 Iteration: 12400 Avg. Training loss: 3.3735 1.0572 sec/batch
# Epoch 1/5 Iteration: 12500 Avg. Training loss: 3.4417 1.0372 sec/batch
# Epoch 1/5 Iteration: 12600 Avg. Training loss: 3.4549 1.0430 sec/batch
# Epoch 1/5 Iteration: 12700 Avg. Training loss: 3.2609 1.0599 sec/batch
# Epoch 1/5 Iteration: 12800 Avg. Training loss: 3.1181 1.0678 sec/batch
# Epoch 1/5 Iteration: 12900 Avg. Training loss: 3.3538 1.0280 sec/batch
# Epoch 1/5 Iteration: 13000 Avg. Training loss: 3.4508 1.0269 sec/batch
# Nearest to use: emotion, synapses, sable, africa, kaleidoscope, snowbird, outmoded, fischettis,
# Nearest to would: chatterbox, immediately, cranham, reminding, sno, praef, athletics, unflinchingly,
# Nearest to had: funk, bncs, tailgating, has, erators, ira, zemsk, heswall,
# Nearest to when: illuminate, assembled, fluttering, citazione, cordiale, basrah, lucky, yfb,
# Nearest to new: repentant, zervic, edna, kivu, wiley, msrtc, cocawine, kamin,
# Nearest to war: brundtland, twah, energetically, heidi, nokkrum, khalifas, humilitation, parentheticals,
# Nearest to to: dragondos, trotter, nicorette, camel, sete, stirrer, abandoned, impatient,
# Nearest to by: claverie, reducing, asa, uturoa, qasr, sltb, contravariance, silkworth,
# Nearest to freedom: morgenlandfahrt, paros, probably, crockett, despues, thrush, electrically, recordable,
# Nearest to bill: thrown, botomian, fadiman, coanna, tokyo, plastering, aguto, madhukarshah,
# Nearest to prince: sogno, ulcc, hall, halifax, macrobiology, fairfax, heijo, tenth,
# Nearest to placed: quantic, umarkot, kentaga, physicists, yojimbo, overhead, outdueling, restfully,
# Nearest to ice: cisl, mumbi, haydnhaus, cholsey, percussion, juliae, harmar, mmegi,
# Nearest to mathematics: nicht, arabic, abashed, kreiss, difference, mixup, modes, shortcuts,
# Nearest to primarily: cancellation, koran, enmity, reinforced, arrhidaeus, basement, invoke, zerbo,
# Nearest to frac: chirassi, giants, hoonacker, skybolt, spacewalks, macinnis, demonstrated, qualifiers,
# Epoch 1/5 Iteration: 13100 Avg. Training loss: 3.3740 1.0553 sec/batch
# Epoch 1/5 Iteration: 13200 Avg. Training loss: 3.4152 1.0513 sec/batch
# Epoch 1/5 Iteration: 13300 Avg. Training loss: 3.3899 1.0454 sec/batch
# Epoch 1/5 Iteration: 13400 Avg. Training loss: 3.2909 1.0529 sec/batch
# Epoch 1/5 Iteration: 13500 Avg. Training loss: 3.3381 1.0458 sec/batch
# Epoch 1/5 Iteration: 13600 Avg. Training loss: 3.2553 1.0280 sec/batch
# Epoch 1/5 Iteration: 13700 Avg. Training loss: 3.3737 1.0453 sec/batch
# Epoch 1/5 Iteration: 13800 Avg. Training loss: 3.2402 1.0743 sec/batch
# Epoch 1/5 Iteration: 13900 Avg. Training loss: 3.2307 1.1435 sec/batch
# Epoch 1/5 Iteration: 14000 Avg. Training loss: 3.3349 1.1040 sec/batch
# Nearest to use: emotion, synapses, sable, africa, kaleidoscope, snowbird, outfielder, outmoded,
# Nearest to would: chatterbox, immediately, cranham, reminding, sno, athletics, unflinchingly, metaphorically,
# Nearest to had: bncs, tailgating, funk, has, erators, prenzlauer, heswall, zemsk,
# Nearest to when: illuminate, fluttering, citazione, assembled, cordiale, ires, basrah, fungicidal,
# Nearest to new: repentant, zervic, edna, kivu, cocawine, msrtc, romantik, kamin,
# Nearest to war: brundtland, twah, energetically, heidi, nokkrum, humilitation, parentheticals, pallo,
# Nearest to to: dragondos, nicorette, stirrer, abandoned, sete, trotter, mata, impatient,
# Nearest to by: claverie, asa, reducing, uturoa, sltb, contravariance, qasr, silkworth,
# Nearest to freedom: morgenlandfahrt, paros, crockett, despues, probably, thrush, electrically, recordable,
# Nearest to bill: thrown, botomian, fadiman, coanna, aguto, tokyo, plastering, pectus,
# Nearest to prince: ulcc, sogno, heijo, macrobiology, halifax, hall, fairfax, royal,
# Nearest to placed: quantic, umarkot, kentaga, yojimbo, physicists, outdueling, overhead, angelina,
# Nearest to ice: cisl, mumbi, haydnhaus, percussion, cholsey, harmar, juliae, mmegi,
# Nearest to mathematics: nicht, abashed, arabic, kreiss, difference, mixup, modes, shortcuts,
# Nearest to primarily: cancellation, koran, enmity, reinforced, basement, arrhidaeus, zerbo, donovan,
# Nearest to frac: chirassi, giants, hoonacker, skybolt, spacewalks, demonstrated, macinnis, qualifiers,
# Epoch 1/5 Iteration: 14100 Avg. Training loss: 3.2605 1.1173 sec/batch
# Epoch 1/5 Iteration: 14200 Avg. Training loss: 3.3931 1.0949 sec/batch
# Epoch 1/5 Iteration: 14300 Avg. Training loss: 3.2022 1.0815 sec/batch
# Epoch 1/5 Iteration: 14400 Avg. Training loss: 3.3897 1.1602 sec/batch
# Epoch 1/5 Iteration: 14500 Avg. Training loss: 3.3091 1.3124 sec/batch
# Epoch 1/5 Iteration: 14600 Avg. Training loss: 3.3832 1.3158 sec/batch
# Epoch 1/5 Iteration: 14700 Avg. Training loss: 3.2928 1.3154 sec/batch
# Epoch 1/5 Iteration: 14800 Avg. Training loss: 3.2715 1.2520 sec/batch
# Epoch 1/5 Iteration: 14900 Avg. Training loss: 3.3319 1.3030 sec/batch
# Epoch 1/5 Iteration: 15000 Avg. Training loss: 3.1965 1.0626 sec/batch
# Nearest to use: emotion, synapses, sable, kaleidoscope, snowbird, fischettis, africa, outfielder,
# Nearest to would: chatterbox, cranham, immediately, athletics, reminding, sno, unflinchingly, aliso,
# Nearest to had: bncs, tailgating, has, funk, erators, klef, prenzlauer, heswall,
# Nearest to when: illuminate, assembled, fluttering, citazione, cordiale, ires, fungicidal, swasthy,
# Nearest to new: repentant, zervic, edna, kivu, msrtc, romantik, cocawine, wiley,
# Nearest to war: brundtland, twah, energetically, heidi, humilitation, nokkrum, parentheticals, diatonics,
# Nearest to to: dragondos, trotter, nicorette, stirrer, sete, impatient, mata, abandoned,
# Nearest to by: asa, claverie, sltb, contravariance, atfal, bcie, qasr, uturoa,
# Nearest to freedom: morgenlandfahrt, despues, paros, crockett, probably, thrush, recordable, luhansk,
# Nearest to bill: thrown, botomian, fadiman, coanna, aguto, plastering, pectus, madhukarshah,
# Nearest to prince: sogno, ulcc, macrobiology, royal, heijo, hall, halifax, tenth,
# Nearest to placed: quantic, umarkot, kentaga, yojimbo, outdueling, hlte, eyewitnes, triumphalism,
# Nearest to ice: mumbi, cisl, haydnhaus, cholsey, harmar, percussion, juliae, propagated,
# Nearest to mathematics: nicht, abashed, arabic, kreiss, difference, mixup, unmogip, shortcuts,
# Nearest to primarily: cancellation, koran, enmity, reinforced, arrhidaeus, basement, donovan, zerbo,
# Nearest to frac: chirassi, macinnis, skybolt, giants, hoonacker, spacewalks, qualifiers, demonstrated,
# Epoch 1/5 Iteration: 15100 Avg. Training loss: 3.2095 1.0822 sec/batch
# Epoch 1/5 Iteration: 15200 Avg. Training loss: 3.1340 1.0697 sec/batch
# Epoch 1/5 Iteration: 15300 Avg. Training loss: 3.1674 1.0610 sec/batch
# Epoch 1/5 Iteration: 15400 Avg. Training loss: 3.3463 1.0639 sec/batch
# Epoch 1/5 Iteration: 15500 Avg. Training loss: 3.3590 1.0675 sec/batch
# Epoch 1/5 Iteration: 15600 Avg. Training loss: 3.3854 1.0637 sec/batch
# Epoch 1/5 Iteration: 15700 Avg. Training loss: 3.2882 1.0635 sec/batch
# Epoch 1/5 Iteration: 15800 Avg. Training loss: 3.2259 1.0701 sec/batch
# Epoch 1/5 Iteration: 15900 Avg. Training loss: 3.1319 1.0667 sec/batch
# Epoch 1/5 Iteration: 16000 Avg. Training loss: 3.2475 1.0675 sec/batch
# Nearest to use: emotion, synapses, kaleidoscope, sable, snowbird, fischettis, africa, thigh,
# Nearest to would: chatterbox, cranham, immediately, athletics, reminding, metaphorically, ll, sno,
# Nearest to had: has, tailgating, bncs, funk, prenzlauer, heswall, klef, recits,
# Nearest to when: illuminate, assembled, fluttering, citazione, cordiale, whisky, fungicidal, ires,
# Nearest to new: repentant, edna, zervic, kivu, romantik, allotment, mujibur, msrtc,
# Nearest to war: brundtland, twah, energetically, heidi, humilitation, declaration, parentheticals, nokkrum,
# Nearest to to: dragondos, trotter, spanning, nicorette, stirrer, fluorescent, sete, camel,
# Nearest to by: claverie, asa, uturoa, atfal, qasr, bcie, sltb, contravariance,
# Nearest to freedom: morgenlandfahrt, despues, crockett, paros, thrush, probably, luhansk, recordable,
# Nearest to bill: thrown, botomian, fadiman, aguto, coanna, phenanthrine, plastering, polygalales,
# Nearest to prince: sogno, ulcc, macrobiology, royal, halifax, heijo, fairfax, hall,
# Nearest to placed: quantic, umarkot, kentaga, yojimbo, outdueling, eyewitnes, hlte, triumphalism,
# Nearest to ice: mumbi, cisl, haydnhaus, harmar, cholsey, percussion, juliae, propagated,
# Nearest to mathematics: nicht, abashed, arabic, kreiss, modes, shortcuts, difference, unmogip,
# Nearest to primarily: cancellation, koran, enmity, arrhidaeus, reinforced, donovan, zerbo, hooramarju,
# Nearest to frac: chirassi, skybolt, macinnis, hoonacker, spacewalks, giants, qualifiers, aldiss,
# Epoch 1/5 Iteration: 16100 Avg. Training loss: 3.1586 1.0919 sec/batch
# Epoch 1/5 Iteration: 16200 Avg. Training loss: 3.1299 1.0687 sec/batch
# Epoch 1/5 Iteration: 16300 Avg. Training loss: 3.2650 1.0689 sec/batch
# Epoch 1/5 Iteration: 16400 Avg. Training loss: 3.2922 1.0682 sec/batch
# Epoch 1/5 Iteration: 16500 Avg. Training loss: 3.3470 1.0677 sec/batch
# Epoch 1/5 Iteration: 16600 Avg. Training loss: 3.3519 1.0690 sec/batch
# Epoch 1/5 Iteration: 16700 Avg. Training loss: 3.2175 1.0671 sec/batch
# Epoch 1/5 Iteration: 16800 Avg. Training loss: 3.3721 1.0715 sec/batch
# Epoch 1/5 Iteration: 16900 Avg. Training loss: 3.2650 1.0697 sec/batch
# Epoch 1/5 Iteration: 17000 Avg. Training loss: 3.3010 1.0866 sec/batch
# Nearest to use: emotion, sable, synapses, kaleidoscope, snowbird, fischettis, outmoded, africa,
# Nearest to would: chatterbox, cranham, athletics, metaphorically, unflinchingly, sno, immediately, ll,
# Nearest to had: has, bncs, tailgating, funk, klef, prenzlauer, cadillac, corowa,
# Nearest to when: illuminate, assembled, cordiale, fluttering, citazione, whisky, fungicidal, swasthy,
# Nearest to new: repentant, zervic, edna, kivu, allotment, romantik, wiley, msrtc,
# Nearest to war: brundtland, twah, energetically, heidi, parentheticals, nokkrum, diatonics, appetite,
# Nearest to to: dragondos, fluorescent, stirrer, nicorette, trotter, camel, myachkovskian, spanning,
# Nearest to by: asa, claverie, atfal, qasr, bcie, uturoa, contravariance, wissenschaftlichen,
# Nearest to freedom: morgenlandfahrt, despues, crockett, paros, thrush, luhansk, probably, obes,
# Nearest to bill: thrown, botomian, fadiman, aguto, coanna, phenanthrine, madhukarshah, polygalales,
# Nearest to prince: ulcc, sogno, heijo, royal, macrobiology, halifax, fairfax, hall,
# Nearest to placed: quantic, umarkot, kentaga, yojimbo, eyewitnes, triumphalism, blanqui, libice,
# Nearest to ice: mumbi, haydnhaus, cholsey, cisl, juliae, propagated, harmar, percussion,
# Nearest to mathematics: nicht, abashed, kreiss, arabic, unmogip, modes, difference, shortcuts,
# Nearest to primarily: cancellation, koran, arrhidaeus, enmity, reinforced, donovan, zerbo, druze,
# Nearest to frac: chirassi, skybolt, macinnis, hoonacker, spacewalks, giants, qualifiers, aldiss,
# Epoch 1/5 Iteration: 17100 Avg. Training loss: 3.1176 1.1599 sec/batch
# Epoch 1/5 Iteration: 17200 Avg. Training loss: 3.2009 1.1677 sec/batch
# Epoch 1/5 Iteration: 17300 Avg. Training loss: 3.2639 1.1548 sec/batch
# Epoch 1/5 Iteration: 17400 Avg. Training loss: 3.2396 1.0905 sec/batch
# Epoch 1/5 Iteration: 17500 Avg. Training loss: 3.2695 1.0558 sec/batch
# Epoch 1/5 Iteration: 17600 Avg. Training loss: 3.2606 1.0687 sec/batch
# Epoch 1/5 Iteration: 17700 Avg. Training loss: 3.3004 1.0570 sec/batch
# Epoch 1/5 Iteration: 17800 Avg. Training loss: 3.3151 1.0680 sec/batch
# Epoch 1/5 Iteration: 17900 Avg. Training loss: 3.1937 1.0563 sec/batch
# Epoch 1/5 Iteration: 18000 Avg. Training loss: 3.2611 1.0611 sec/batch
# Nearest to use: emotion, sable, synapses, kaleidoscope, snowbird, africa, fischettis, outmoded,
# Nearest to would: chatterbox, cranham, blunted, reminding, athletics, achan, metaphorically, ll,
# Nearest to had: has, tailgating, bncs, funk, klef, zemsk, gresser, erators,
# Nearest to when: illuminate, citazione, cordiale, fluttering, ensucklopedia, assembled, whisky, swasthy,
# Nearest to new: repentant, zervic, edna, allotment, mujibur, romantik, kivu, wiley,
# Nearest to war: brundtland, twah, energetically, parentheticals, heidi, diatonics, nokkrum, khalifas,
# Nearest to to: fluorescent, dragondos, trotter, nicorette, stirrer, myachkovskian, sete, camel,
# Nearest to by: asa, atfal, contravariance, qasr, claverie, uturoa, bcie, wissenschaftlichen,
# Nearest to freedom: morgenlandfahrt, despues, crockett, paros, thrush, luhansk, obes, schwer,
# Nearest to bill: thrown, botomian, fadiman, coanna, aguto, plastering, tokyo, phenanthrine,
# Nearest to prince: ulcc, heijo, sogno, macrobiology, royal, nafe, halifax, hall,
# Nearest to placed: quantic, umarkot, kentaga, eyewitnes, hlte, yojimbo, triumphalism, overhead,
# Nearest to ice: mumbi, cholsey, juliae, cisl, haydnhaus, harmar, propagated, percussion,
# Nearest to mathematics: nicht, abashed, kreiss, arabic, modes, unmogip, difference, hambling,
# Nearest to primarily: cancellation, koran, arrhidaeus, enmity, donovan, reinforced, zerbo, grizzlybear,
# Nearest to frac: chirassi, skybolt, macinnis, hoonacker, spacewalks, giants, qualifiers, aldiss,
# Epoch 1/5 Iteration: 18100 Avg. Training loss: 3.1877 1.0860 sec/batch
# Epoch 1/5 Iteration: 18200 Avg. Training loss: 3.0627 1.0672 sec/batch
# Epoch 1/5 Iteration: 18300 Avg. Training loss: 3.0052 1.0710 sec/batch
# Epoch 1/5 Iteration: 18400 Avg. Training loss: 2.9622 1.0785 sec/batch
# Epoch 1/5 Iteration: 18500 Avg. Training loss: 2.8042 1.0720 sec/batch
# Epoch 1/5 Iteration: 18600 Avg. Training loss: 2.7543 1.0675 sec/batch
# Epoch 1/5 Iteration: 18700 Avg. Training loss: 3.2401 1.0767 sec/batch
# Epoch 1/5 Iteration: 18800 Avg. Training loss: 3.0758 1.0738 sec/batch
# Epoch 1/5 Iteration: 18900 Avg. Training loss: 3.3071 1.0665 sec/batch
# Epoch 1/5 Iteration: 19000 Avg. Training loss: 3.3683 1.0611 sec/batch
# Nearest to use: emotion, sable, kaleidoscope, africa, synapses, fischettis, snowbird, outmoded,
# Nearest to would: chatterbox, blunted, cranham, immediately, hizzoner, metaphorically, athletics, achan,
# Nearest to had: has, tailgating, bncs, klef, recits, vab, gresser, corowa,
# Nearest to when: illuminate, citazione, assembled, cordiale, fluttering, ensucklopedia, whisky, velis,
# Nearest to new: repentant, zervic, edna, allotment, mujibur, romantik, herbivores, cocawine,
# Nearest to war: brundtland, twah, parentheticals, energetically, diatonics, heidi, khalifas, kook,
# Nearest to to: fluorescent, trotter, stirrer, dragondos, nicorette, mediagenic, sete, rhine,
# Nearest to by: qasr, asa, uturoa, atfal, claverie, contravariance, richtmyer, government,
# Nearest to freedom: morgenlandfahrt, despues, crockett, paros, thrush, probably, luhansk, obes,
# Nearest to bill: thrown, botomian, fadiman, aguto, coanna, tokyo, phenanthrine, plastering,
# Nearest to prince: ulcc, heijo, sogno, royal, macrobiology, nafe, halifax, fairfax,
# Nearest to placed: quantic, umarkot, eyewitnes, kentaga, overhead, triumphalism, hlte, yojimbo,
# Nearest to ice: mumbi, cholsey, juliae, percussion, cisl, haydnhaus, harmar, propagated,
# Nearest to mathematics: nicht, abashed, arabic, kreiss, modes, hambling, unmogip, shortcuts,
# Nearest to primarily: cancellation, koran, arrhidaeus, zerbo, donovan, enmity, hooramarju, hirah,
# Nearest to frac: chirassi, skybolt, macinnis, hoonacker, spacewalks, giants, qualifiers, aldiss,
# Epoch 1/5 Iteration: 19100 Avg. Training loss: 3.3152 1.0824 sec/batch
# Epoch 1/5 Iteration: 19200 Avg. Training loss: 3.2521 1.0719 sec/batch
# Epoch 1/5 Iteration: 19300 Avg. Training loss: 3.2950 1.0655 sec/batch
# Epoch 1/5 Iteration: 19400 Avg. Training loss: 3.2768 1.0663 sec/batch
# Epoch 1/5 Iteration: 19500 Avg. Training loss: 3.3003 1.0723 sec/batch
# Epoch 1/5 Iteration: 19600 Avg. Training loss: 3.3595 1.0771 sec/batch
# Epoch 1/5 Iteration: 19700 Avg. Training loss: 2.9665 1.0726 sec/batch
# Epoch 1/5 Iteration: 19800 Avg. Training loss: 3.2036 1.0801 sec/batch
# Epoch 1/5 Iteration: 19900 Avg. Training loss: 3.1788 1.0797 sec/batch
# Epoch 1/5 Iteration: 20000 Avg. Training loss: 3.1368 1.1003 sec/batch
# Nearest to use: emotion, sable, kaleidoscope, synapses, fischettis, snowbird, africa, outmoded,
# Nearest to would: chatterbox, immediately, blunted, hizzoner, sno, achan, unflinchingly, cranham,
# Nearest to had: has, tailgating, bncs, vab, recits, naan, micronutrient, zemsk,
# Nearest to when: citazione, illuminate, fluttering, assembled, cordiale, ensucklopedia, swasthy, orchids,
# Nearest to new: repentant, edna, zervic, allotment, romantik, overstaying, herbivores, plough,
# Nearest to war: brundtland, twah, energetically, parentheticals, heidi, diatonics, nokkrum, declaration,
# Nearest to to: impatient, fluorescent, rhine, dragondos, trotter, mediagenic, differently, myachkovskian,
# Nearest to by: atfal, qasr, asa, wissenschaftlichen, richtmyer, bcie, claverie, uturoa,
# Nearest to freedom: morgenlandfahrt, despues, crockett, paros, thrush, probably, luhansk, obes,
# Nearest to bill: thrown, botomian, fadiman, tokyo, polygalales, madhukarshah, coanna, plastering,
# Nearest to prince: ulcc, royal, heijo, sogno, macrobiology, hall, nafe, fairfax,
# Nearest to placed: quantic, umarkot, kentaga, yojimbo, overhead, eyewitnes, outdueling, libice,
# Nearest to ice: mumbi, cholsey, cisl, juliae, harmar, percussion, haydnhaus, mmegi,
# Nearest to mathematics: abashed, nicht, arabic, kreiss, modes, unmogip, hambling, supersampler,
# Nearest to primarily: cancellation, koran, zerbo, donovan, mlahs, arrhidaeus, hirah, enmity,
# Nearest to frac: chirassi, macinnis, skybolt, qualifiers, hoonacker, aldiss, echinocereus, spacewalks,
# Epoch 1/5 Iteration: 20100 Avg. Training loss: 3.2229 1.1224 sec/batch
# Epoch 1/5 Iteration: 20200 Avg. Training loss: 3.2618 1.0899 sec/batch
# Epoch 1/5 Iteration: 20300 Avg. Training loss: 3.2192 1.0751 sec/batch
# Epoch 1/5 Iteration: 20400 Avg. Training loss: 3.1928 1.0764 sec/batch
# Epoch 1/5 Iteration: 20500 Avg. Training loss: 3.1312 1.1054 sec/batch
# Epoch 1/5 Iteration: 20600 Avg. Training loss: 3.0943 1.0736 sec/batch
# Epoch 1/5 Iteration: 20700 Avg. Training loss: 3.0877 1.0754 sec/batch
# Epoch 1/5 Iteration: 20800 Avg. Training loss: 3.0998 1.0715 sec/batch
# Epoch 1/5 Iteration: 20900 Avg. Training loss: 3.3116 1.0753 sec/batch
# Epoch 1/5 Iteration: 21000 Avg. Training loss: 3.2480 1.0790 sec/batch
# Nearest to use: emotion, sable, kaleidoscope, synapses, fischettis, snowbird, africa, outmoded,
# Nearest to would: chatterbox, immediately, blunted, unflinchingly, sno, hizzoner, achan, athletics,
# Nearest to had: has, tailgating, bncs, vab, recits, ira, releaed, advisability,
# Nearest to when: citazione, illuminate, fluttering, assembled, orchids, ensucklopedia, velis, swasthy,
# Nearest to new: repentant, edna, zervic, romantik, allotment, overstaying, herbivores, plough,
# Nearest to war: brundtland, twah, parentheticals, energetically, nokkrum, declaration, khalifas, diatonics,
# Nearest to to: impatient, fluorescent, differently, rhine, canonic, mediagenic, covenants, trotter,
# Nearest to by: atfal, qasr, uturoa, bcie, claverie, wissenschaftlichen, shutruk, casterman,
# Nearest to freedom: morgenlandfahrt, despues, crockett, paros, thrush, luhansk, obes, schwer,
# Nearest to bill: thrown, botomian, fadiman, tokyo, coanna, madhukarshah, plastering, polygalales,
# Nearest to prince: ulcc, royal, heijo, sogno, nafe, macrobiology, obstinate, hall,
# Nearest to placed: quantic, umarkot, kentaga, eyewitnes, libice, yojimbo, blanqui, tempos,
# Nearest to ice: mumbi, cholsey, juliae, cisl, propagated, percussion, haydnhaus, harmar,
# Nearest to mathematics: nicht, abashed, arabic, kreiss, modes, hambling, interdisciplinary, unmogip,
# Nearest to primarily: cancellation, koran, zerbo, mlahs, arrhidaeus, donovan, grizzlybear, hirah,
# Nearest to frac: chirassi, macinnis, skybolt, hoonacker, qualifiers, spacewalks, aldiss, giants,
# Epoch 1/5 Iteration: 21100 Avg. Training loss: 3.0491 1.1052 sec/batch
# Epoch 1/5 Iteration: 21200 Avg. Training loss: 3.2432 1.0763 sec/batch
# Epoch 1/5 Iteration: 21300 Avg. Training loss: 3.2387 1.1367 sec/batch
# Epoch 1/5 Iteration: 21400 Avg. Training loss: 3.3470 1.4255 sec/batch
# Epoch 1/5 Iteration: 21500 Avg. Training loss: 3.1727 1.2812 sec/batch
# Epoch 1/5 Iteration: 21600 Avg. Training loss: 3.2311 1.3656 sec/batch
# Epoch 1/5 Iteration: 21700 Avg. Training loss: 3.2134 1.3377 sec/batch
# Epoch 1/5 Iteration: 21800 Avg. Training loss: 3.1715 1.4014 sec/batch
# Epoch 1/5 Iteration: 21900 Avg. Training loss: 3.2620 1.2386 sec/batch
# Epoch 1/5 Iteration: 22000 Avg. Training loss: 3.0682 1.2600 sec/batch
# Nearest to use: emotion, kaleidoscope, sable, snowbird, fischettis, synapses, langsyne, keenly,
# Nearest to would: chatterbox, blunted, immediately, unflinchingly, sno, hizzoner, achan, ll,
# Nearest to had: has, tailgating, bncs, vab, recits, micronutrient, advisability, funk,
# Nearest to when: illuminate, citazione, fluttering, assembled, wife, ensucklopedia, orchids, whisky,
# Nearest to new: repentant, zervic, edna, romantik, allotment, overstaying, plough, paneriai,
# Nearest to war: brundtland, twah, parentheticals, energetically, nokkrum, pallo, khalifas, heidi,
# Nearest to to: impatient, differently, fluorescent, canonic, rhine, offroad, trotter, ordered,
# Nearest to by: atfal, qasr, figaro, wissenschaftlichen, bcie, asa, richtmyer, uturoa,
# Nearest to freedom: morgenlandfahrt, despues, crockett, thrush, luhansk, paros, obes, schwer,
# Nearest to bill: thrown, botomian, fadiman, tokyo, plastering, coanna, polygalales, madhukarshah,
# Nearest to prince: ulcc, heijo, royal, sogno, macrobiology, nafe, hall, terminating,
# Nearest to placed: quantic, umarkot, eyewitnes, libice, yojimbo, kentaga, amss, tempos,
# Nearest to ice: mumbi, cholsey, juliae, propagated, percussion, cisl, mmegi, haydnhaus,
# ...
# Nearest to frac: chirassi, macinnis, skybolt, hoonacker, spacewalks, giants, qualifiers, aldiss,
# Epoch 1/5 Iteration: 22100 Avg. Training loss: 3.0240 1.2064 sec/batch
# Epoch 1/5 Iteration: 22200 Avg. Training loss: 3.0573 1.0954 sec/batch
# Epoch 1/5 Iteration: 22300 Avg. Training loss: 3.2282 1.0924 sec/batch
# Epoch 1/5 Iteration: 22400 Avg. Training loss: 3.2225 1.1039 sec/batch
# Epoch 1/5 Iteration: 22500 Avg. Training loss: 3.2536 1.0920 sec/batch
# Epoch 1/5 Iteration: 22600 Avg. Training loss: 3.1119 1.1271 sec/batch
# Epoch 1/5 Iteration: 22700 Avg. Training loss: 3.2375 1.3820 sec/batch
# Epoch 1/5 Iteration: 22800 Avg. Training loss: 3.1492 1.3043 sec/batch
# Epoch 1/5 Iteration: 22900 Avg. Training loss: 3.1907 1.3694 sec/batch
# Epoch 1/5 Iteration: 23000 Avg. Training loss: 3.2681 1.3699 sec/batch
# Nearest to use: emotion, kaleidoscope, sable, langsyne, fischettis, culbert, africa, snowbird,
# Nearest to would: chatterbox, ll, achan, blunted, unflinchingly, sno, basso, immediately,
# Nearest to had: has, tailgating, vab, bncs, recits, funk, deejaying, micronutrient,
# Nearest to when: illuminate, citazione, fluttering, assembled, ensucklopedia, orchids, bungert, matsunoyuki,
# Nearest to new: repentant, edna, zervic, romantik, overstaying, allotment, especialy, herbivores,
# Nearest to war: brundtland, twah, parentheticals, nokkrum, pallo, khalifas, powertrain, heidi,
# Nearest to to: impatient, fluorescent, dragondos, mediagenic, trotter, offroad, differently, rhine,
# Nearest to by: atfal, claverie, wissenschaftlichen, bcie, qasr, uturoa, shutruk, asa,
# Nearest to freedom: morgenlandfahrt, despues, crockett, thrush, paros, luhansk, schwer, obes,
# Nearest to bill: thrown, botomian, fadiman, tokyo, polygalales, coanna, plastering, madhukarshah,
# Nearest to prince: ulcc, heijo, royal, nafe, macrobiology, sogno, obstinate, hall,
# Nearest to placed: quantic, umarkot, eyewitnes, libice, amss, tempos, yojimbo, kentaga,
# Nearest to ice: mumbi, cholsey, juliae, percussion, propagated, mmegi, harmar, haydnhaus,
# Nearest to mathematics: abashed, nicht, kreiss, arabic, interdisciplinary, modes, soaker, hambling,
# Nearest to primarily: cancellation, koran, donovan, zerbo, mlahs, hirah, enmity, grizzlybear,
# Nearest to frac: chirassi, macinnis, skybolt, qualifiers, hoonacker, spacewalks, aldiss, giants,
# Epoch 1/5 Iteration: 23100 Avg. Training loss: 3.0788 1.3371 sec/batch
# Epoch 1/5 Iteration: 23200 Avg. Training loss: 3.0774 1.3639 sec/batch
# Epoch 1/5 Iteration: 23300 Avg. Training loss: 3.0980 1.3490 sec/batch
# Epoch 1/5 Iteration: 23400 Avg. Training loss: 3.1896 1.3787 sec/batch
# Epoch 1/5 Iteration: 23500 Avg. Training loss: 3.1336 1.3461 sec/batch
# Epoch 1/5 Iteration: 23600 Avg. Training loss: 3.0056 1.3799 sec/batch
# Epoch 1/5 Iteration: 23700 Avg. Training loss: 3.1045 1.0984 sec/batch
# Epoch 1/5 Iteration: 23800 Avg. Training loss: 3.1895 1.0882 sec/batch
# Epoch 1/5 Iteration: 23900 Avg. Training loss: 3.0535 1.0880 sec/batch
# Epoch 1/5 Iteration: 24000 Avg. Training loss: 3.0898 1.0869 sec/batch
# Nearest to use: emotion, kaleidoscope, sable, langsyne, metatonic, culbert, zizia, fischettis,
# Nearest to would: chatterbox, ll, achan, basso, sno, unflinchingly, immediately, blunted,
# Nearest to had: has, tailgating, vab, bncs, deejaying, micronutrient, lemkos, advisability,
# Nearest to when: fluttering, citazione, assembled, illuminate, ensucklopedia, orchids, sugarwoods, matsunoyuki,
# Nearest to new: repentant, zervic, edna, romantik, allotment, especialy, overstaying, herbivores,
# Nearest to war: brundtland, twah, nokkrum, parentheticals, pallo, khalifas, powertrain, jonny,
# Nearest to to: dragondos, differently, offroad, impatient, canonic, trotter, mediagenic, fluorescent,
# Nearest to by: atfal, claverie, wissenschaftlichen, qasr, novaehollandiae, uturoa, figaro, wireline,
# Nearest to freedom: morgenlandfahrt, despues, paros, crockett, thrush, luhansk, schwer, obes,
# Nearest to bill: thrown, botomian, fadiman, polygalales, madhukarshah, coanna, pectus, phenanthrine,
# Nearest to prince: ulcc, heijo, nafe, royal, macrobiology, sogno, obstinate, adsp,
# Nearest to placed: quantic, umarkot, eyewitnes, tempos, libice, yojimbo, kentaga, amss,
# Nearest to ice: mumbi, cholsey, juliae, percussion, propagated, harmar, haydnhaus, mmegi,
# Nearest to mathematics: abashed, nicht, kreiss, modes, arabic, interdisciplinary, soaker, polops,
# Nearest to primarily: koran, cancellation, mlahs, hooramarju, donovan, hirah, grizzlybear, zerbo,
# Nearest to frac: chirassi, macinnis, skybolt, qualifiers, hoonacker, spacewalks, aldiss, giants,
# Epoch 1/5 Iteration: 24100 Avg. Training loss: 3.1008 1.1086 sec/batch
# Epoch 1/5 Iteration: 24200 Avg. Training loss: 3.0824 1.0895 sec/batch
# Epoch 1/5 Iteration: 24300 Avg. Training loss: 3.1062 1.0934 sec/batch
# Epoch 1/5 Iteration: 24400 Avg. Training loss: 3.1428 1.0914 sec/batch
# Epoch 1/5 Iteration: 24500 Avg. Training loss: 3.2637 1.0897 sec/batch
# Epoch 1/5 Iteration: 24600 Avg. Training loss: 3.1201 1.0906 sec/batch
# Epoch 1/5 Iteration: 24700 Avg. Training loss: 3.0432 1.0922 sec/batch
# Epoch 1/5 Iteration: 24800 Avg. Training loss: 3.0633 1.0896 sec/batch
# Epoch 1/5 Iteration: 24900 Avg. Training loss: 3.1181 1.0883 sec/batch
# Epoch 1/5 Iteration: 25000 Avg. Training loss: 3.0699 1.0931 sec/batch
# Nearest to use: emotion, kaleidoscope, sable, diligence, metatonic, zizia, keenly, langsyne,
# Nearest to would: chatterbox, ll, blunted, achan, unflinchingly, immediately, sno, basso,
# Nearest to had: has, tailgating, bncs, vab, micronutrient, naan, advisability, deejaying,
# Nearest to when: fluttering, illuminate, citazione, assembled, ensucklopedia, hahnemann, bungert, wife,
# Nearest to new: repentant, edna, zervic, romantik, allotment, especialy, paneriai, overstaying,
# Nearest to war: brundtland, twah, nokkrum, parentheticals, pallo, jonny, powertrain, energetically,
# Nearest to to: offroad, trotter, differently, canonic, impatient, dragondos, fluorescent, overs,
# Nearest to by: claverie, atfal, wissenschaftlichen, figaro, qasr, ethnohistorical, uturoa, asa,
# Nearest to freedom: morgenlandfahrt, despues, crockett, paros, luhansk, thrush, recordable, obes,
# Nearest to bill: thrown, botomian, fadiman, madhukarshah, coanna, bowed, pectus, corral,
# Nearest to prince: ulcc, heijo, nafe, royal, macrobiology, sogno, obstinate, dealt,
# Nearest to placed: quantic, umarkot, eyewitnes, yojimbo, kentaga, tempos, amss, libice,
# Nearest to ice: juliae, mumbi, cholsey, percussion, propagated, haydnhaus, harmar, mmegi,
# Nearest to mathematics: abashed, nicht, kreiss, arabic, modes, polops, interdisciplinary, soaker,
# Nearest to primarily: cancellation, koran, mlahs, zerbo, donovan, hirah, hooramarju, grizzlybear,
# Nearest to frac: chirassi, macinnis, hoonacker, skybolt, qualifiers, aldiss, spacewalks, upcoding,
# Epoch 1/5 Iteration: 25100 Avg. Training loss: 3.2754 1.2865 sec/batch
# Epoch 1/5 Iteration: 25200 Avg. Training loss: 3.1830 1.3827 sec/batch
# Epoch 1/5 Iteration: 25300 Avg. Training loss: 3.2472 1.3872 sec/batch
# Epoch 1/5 Iteration: 25400 Avg. Training loss: 3.1605 1.3925 sec/batch
# Epoch 1/5 Iteration: 25500 Avg. Training loss: 3.2618 1.3485 sec/batch
# Epoch 1/5 Iteration: 25600 Avg. Training loss: 3.2068 1.1872 sec/batch
# Epoch 1/5 Iteration: 25700 Avg. Training loss: 3.2426 1.3146 sec/batch
# Epoch 1/5 Iteration: 25800 Avg. Training loss: 3.2069 1.3592 sec/batch
# Epoch 1/5 Iteration: 25900 Avg. Training loss: 3.0498 1.3443 sec/batch
# Epoch 1/5 Iteration: 26000 Avg. Training loss: 3.1811 1.2205 sec/batch
# Nearest to use: emotion, kaleidoscope, sable, culbert, zizia, snowbird, africa, langsyne,
# Nearest to would: chatterbox, blunted, unflinchingly, ll, achan, sno, immediately, hizzoner,
# Nearest to had: has, bncs, micronutrient, tailgating, deejaying, naan, vab, lancaster,
# Nearest to when: fluttering, assembled, illuminate, citazione, ensucklopedia, cordiale, orchids, ires,
# Nearest to new: repentant, edna, zervic, romantik, allotment, overstaying, especialy, paneriai,
# Nearest to war: brundtland, twah, parentheticals, nokkrum, fighter, powertrain, pallo, jonny,
# Nearest to to: offroad, dragondos, fluorescent, trotter, differently, alkene, mediagenic, canonic,
# Nearest to by: claverie, atfal, qasr, wissenschaftlichen, uturoa, figaro, asa, bcie,
# Nearest to freedom: morgenlandfahrt, despues, paros, crockett, luhansk, thrush, schwer, recordable,
# Nearest to bill: thrown, botomian, fadiman, madhukarshah, pectus, polygalales, coanna, aguto,
# Nearest to prince: ulcc, heijo, nafe, macrobiology, slates, royal, obstinate, sogno,
# Nearest to placed: quantic, umarkot, eyewitnes, yojimbo, kentaga, netstat, libice, amss,
# Nearest to ice: juliae, mumbi, cholsey, percussion, harmar, haydnhaus, cisl, propagated,
# Nearest to mathematics: abashed, nicht, kreiss, soaker, modes, polops, arabic, cortical,
# Nearest to primarily: koran, cancellation, mlahs, zerbo, hirah, donovan, grizzlybear, sivewright,
# Nearest to frac: aldiss, chirassi, hoonacker, macinnis, skybolt, qualifiers, spacewalks, upcoding,
# Epoch 1/5 Iteration: 26100 Avg. Training loss: 3.1985 1.1361 sec/batch
# Epoch 1/5 Iteration: 26200 Avg. Training loss: 3.1838 1.1013 sec/batch
# Epoch 1/5 Iteration: 26300 Avg. Training loss: 3.2018 1.1064 sec/batch
# Epoch 1/5 Iteration: 26400 Avg. Training loss: 3.1142 1.1292 sec/batch
# Epoch 1/5 Iteration: 26500 Avg. Training loss: 3.2079 1.1892 sec/batch
# Epoch 1/5 Iteration: 26600 Avg. Training loss: 3.1582 1.1550 sec/batch
# Epoch 1/5 Iteration: 26700 Avg. Training loss: 3.1090 1.1748 sec/batch
# Epoch 1/5 Iteration: 26800 Avg. Training loss: 3.1377 1.1811 sec/batch
# Epoch 1/5 Iteration: 26900 Avg. Training loss: 3.1544 1.2177 sec/batch
# Epoch 1/5 Iteration: 27000 Avg. Training loss: 3.1927 1.1749 sec/batch
# Nearest to use: emotion, sable, kaleidoscope, culbert, zizia, spermicide, africa, diligence,
# Nearest to would: unflinchingly, chatterbox, ll, hizzoner, metaphorically, blunted, achan, immediately,
# Nearest to had: has, micronutrient, bncs, klef, lancaster, tailgating, undutiful, deejaying,
# Nearest to when: fluttering, ensucklopedia, illuminate, assembled, ires, citazione, cordiale, orchids,
# Nearest to new: repentant, edna, zervic, allotment, romantik, overstaying, especialy, calorimeter,
# Nearest to war: brundtland, twah, parentheticals, nokkrum, fighter, powertrain, hiramatsu, pallo,
# Nearest to to: offroad, fluorescent, dragondos, trotter, differently, alkene, spamfilter, nicorette,
# Nearest to by: wissenschaftlichen, bcie, claverie, qasr, atfal, figaro, uturoa, novaehollandiae,
# Nearest to freedom: morgenlandfahrt, despues, paros, luhansk, crockett, thrush, schwer, obes,
# Nearest to bill: thrown, botomian, fadiman, madhukarshah, pectus, coanna, aguto, polygalales,
# Nearest to prince: ulcc, heijo, nafe, royal, sogno, macrobiology, obstinate, adsp,
# Nearest to placed: quantic, umarkot, eyewitnes, kentaga, yojimbo, netstat, tempos, amss,
# Nearest to ice: juliae, mumbi, cholsey, percussion, haydnhaus, harmar, cisl, mmegi,
# Nearest to mathematics: abashed, kreiss, nicht, modes, soaker, arabic, cortical, polops,
# Nearest to primarily: koran, zerbo, mlahs, cancellation, hirah, donovan, hooramarju, grizzlybear,
# Nearest to frac: aldiss, chirassi, skybolt, macinnis, spacewalks, qualifiers, upcoding, hoonacker,
# Epoch 1/5 Iteration: 27100 Avg. Training loss: 3.2392 1.2178 sec/batch
# Epoch 1/5 Iteration: 27200 Avg. Training loss: 3.1315 1.2092 sec/batch
# Epoch 1/5 Iteration: 27300 Avg. Training loss: 3.0954 1.2237 sec/batch
# Epoch 1/5 Iteration: 27400 Avg. Training loss: 3.1718 1.2319 sec/batch
# Epoch 1/5 Iteration: 27500 Avg. Training loss: 3.1002 1.2090 sec/batch
# Epoch 1/5 Iteration: 27600 Avg. Training loss: 3.1752 1.1969 sec/batch
# Epoch 1/5 Iteration: 27700 Avg. Training loss: 3.1943 1.2088 sec/batch
# Epoch 1/5 Iteration: 27800 Avg. Training loss: 3.2395 1.1968 sec/batch
# Epoch 1/5 Iteration: 27900 Avg. Training loss: 3.1505 1.1480 sec/batch
# Epoch 1/5 Iteration: 28000 Avg. Training loss: 3.1083 1.2243 sec/batch
# Nearest to use: emotion, kaleidoscope, sable, zizia, culbert, diligence, spermicide, keenly,
# Nearest to would: chatterbox, unflinchingly, metaphorically, ll, immediately, blunted, hizzoner, achan,
# Nearest to had: has, bncs, micronutrient, klef, lancaster, tailgating, advisability, undutiful,
# Nearest to when: illuminate, fluttering, ensucklopedia, assembled, citazione, ires, sugarwoods, orchids,
# Nearest to new: repentant, edna, zervic, allotment, overstaying, romantik, especialy, calorimeter,
# Nearest to war: brundtland, fighter, parentheticals, twah, nokkrum, hiramatsu, powertrain, heidi,
# Nearest to to: dragondos, nicorette, alkene, trotter, offroad, spamfilter, fluorescent, ordered,
# Nearest to by: wissenschaftlichen, claverie, qasr, figaro, bcie, atfal, casterman, richtmyer,
# Nearest to freedom: morgenlandfahrt, despues, paros, luhansk, thrush, crockett, schwer, obes,
# Nearest to bill: thrown, botomian, fadiman, madhukarshah, pectus, bowed, coanna, phenanthrine,
# Nearest to prince: heijo, ulcc, nafe, sogno, obstinate, royal, adsp, macrobiology,
# Nearest to placed: quantic, umarkot, eyewitnes, kentaga, netstat, yojimbo, amss, adana,
# Nearest to ice: juliae, mumbi, cholsey, harmar, percussion, haydnhaus, mcimail, shcheglovo,
# Nearest to mathematics: abashed, kreiss, modes, soaker, nicht, arabic, cortical, shortcuts,
# Nearest to primarily: koran, mlahs, zerbo, cancellation, hirah, hooramarju, donovan, grizzlybear,
# Nearest to frac: aldiss, chirassi, macinnis, skybolt, qualifiers, upcoding, spacewalks, hoonacker,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-137-37cf1e7a7d2b> in <module>()
#      18             feed = {inputs: x,
#      19                     labels: np.array(y)[:, None]}
# ---> 20             train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
#      21
#      22             loss += train_loss
#
# D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#
# D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#
# D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\framework\errors_impl.py in raise_exception_on_not_ok_status()
#     468           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 469           pywrap_tensorflow.TF_GetCode(status))
#     470   finally:
#
# NotFoundError: Key Variable/Adam not found in checkpoint
# 	 [[Node: save_1/RestoreV2_1 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_1/Const_0, save_1/RestoreV2_1/tensor_names, save_1/RestoreV2_1/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-138-4eeca6a379f0> in <module>()
#       3
#       4 with tf.Session(graph=train_graph) as sess:
# ----> 5     saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
#       6     embed_mat = sess.run(embedding)
#
# D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1437       return
#    1438     sess.run(self.saver_def.restore_op_name,
# -> 1439              {self.saver_def.filename_tensor_name: save_path})
#    1440
#    1441   @staticmethod
#
# D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1033         except KeyError:
#    1034           pass
# -> 1035       raise type(e)(node_def, op, message)
#    1036
#    1037   def _extend_graph(self):
#
# NotFoundError: Key Variable/Adam not found in checkpoint
# 	 [[Node: save_1/RestoreV2_1 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_1/Const_0, save_1/RestoreV2_1/tensor_names, save_1/RestoreV2_1/shape_and_slices)]]
#
# Caused by op 'save_1/RestoreV2_1', defined at:
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\ipykernel\__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\ipykernel\kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tornado\ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tornado\stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tornado\stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\ipykernel\kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\ipykernel\kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\ipykernel\kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\ipykernel\zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\IPython\core\interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\IPython\core\interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-138-4eeca6a379f0>", line 2, in <module>
#     saver = tf.train.Saver()
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\training\saver.py", line 1051, in __init__
#     self.build()
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\training\saver.py", line 1081, in build
#     restore_sequentially=self._restore_sequentially)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\training\saver.py", line 675, in build
#     restore_sequentially, reshape)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\training\saver.py", line 402, in _AddRestoreOps
#     tensors = self.restore_op(filename_tensor, saveable, preferred_shard)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\training\saver.py", line 242, in restore_op
#     [spec.tensor.dtype])[0])
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\ops\gen_io_ops.py", line 668, in restore_v2
#     dtypes=dtypes, name=name)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 763, in apply_op
#     op_def=op_def)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\framework\ops.py", line 2395, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "D:\360Downloads\Software\anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\framework\ops.py", line 1264, in __init__
#     self._traceback = _extract_stack()
#
# NotFoundError (see above for traceback): Key Variable/Adam not found in checkpoint
# 	 [[Node: save_1/RestoreV2_1 = RestoreV2[dtypes=[DT_FLOAT], _device="/job:localhost/replica:0/task:0/cpu:0"](_recv_save_1/Const_0, save_1/RestoreV2_1/tensor_names, save_1/RestoreV2_1/shape_and_slices)]]

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
